# %%
import sys
import numpy as np
import pandas as pd
print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("rtyui")
print("There was an issue regarding the installation of the minicode so i am using the virtual environment to run the code")
print("I have created a virtual environment and installed the required packages in it. Now I am running the code in the virtual environment.")
print("And i have submitted it late because i enrolled in the course at the last time.Thank you for your understanding.")
# Out:
# Python: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# NumPy: 2.2.6
# Pandas: 2.3.3
# rtyui
